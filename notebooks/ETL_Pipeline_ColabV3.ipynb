# %% [markdown]
# <a href="https://colab.research.google.com/github/bellDataSc/ETL-PROJECT-PYTHON-GCP/blob/main/ETL_Pipeline_ColabV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ETL Pipeline: SIAFEM and SIGEO Data Processing**
#
#
# This notebook illustrates the process I use for work.

# %%
# !pip install pandas google-cloud-bigquery db-dtypes requests -q

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import requests
import json
import os
from google.colab import auth, files
from google.cloud import bigquery

# %%
auth.authenticate_user()

# %% [markdown]
# a service account instead of user authentication...
#
# Upload service account JSON key
#
#       # print('Upload your service account JSON key:')
#       # uploaded = files.upload()
#       # credentials_file = list(uploaded.keys())[0]
#       # os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials_file
#       # print(f'Credentials file set: {credentials_file}')

# %%
PROJECT_ID = 'Dashboard_Preditivo_de_Execução_Orçamentária'
DATASET_ID = 'financial_metrics'
TABLE_ID = 'budget_execution'


SIAFEM_API_URL = None
SIGEO_API_URL = None


client = bigquery.Client(project=PROJECT_ID)
